# %%
import numpy as np
import pandas as pd
import xarray as xr

# %%
file_path = '/scratch/rd53/wy2165/Loibl/'
AAR = []
for i in range(1,7):
    filename = file_path + 'AAR_1985_2021_Loibl_' + str(i) + '.csv';
    df = pd.read_csv(filename).iloc[:, 1:]
    AAR.append(df)
AAR = pd.concat(AAR, axis=1)
AAR = AAR.T
AAR.index.name = 'RGIId'
AAR.columns = np.arange(1985, 2021)

AAR.to_csv('/g/data/rd53/wy2165/snowline_disequilibrium/AAR_1985_2021_Loibl.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 10
#       8 AAR = AAR.T
#       9 AAR.index.name = 'RGIId'
# ---> 10 AAR.columns = np.arange(1985, 2021)
#      12 AAR.to_csv('/g/data/rd53/wy2165/snowline_disequilibrium/AAR_1985_2021_Loibl.csv')
#
# File /g/data/rd53/wy2165/envs/oggm162/lib/python3.10/site-packages/pandas/core/generic.py:6332, in NDFrame.__setattr__(self, name, value)
#    6330 try:
#    6331     object.__getattribute__(self, name)
# -> 6332     return object.__setattr__(self, name, value)
#    6333 except AttributeError:
#    6334     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /g/data/rd53/wy2165/envs/oggm162/lib/python3.10/site-packages/pandas/core/generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
# ...
